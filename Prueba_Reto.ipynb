# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
info = pd.read_csv('/content/drive/MyDrive/1681516462409-AlcoholConsumption.csv')

# %%
info
# Out:
#                 country  alcconsumption  incomeperperson  suicideper100th  \
# 0           Afghanistan            0.03              NaN         6.684385
# 1               Albania            7.29      1914.996551         7.699330
# 2               Algeria            0.69      2231.993335         4.848770
# 3               Andorra           10.17     21943.339900         5.362179
# 4                Angola            5.57      1381.004268        14.554677
# ..                  ...             ...              ...              ...
# 208             Vietnam            3.91       722.807559        11.653322
# 209  West Bank and Gaza             NaN              NaN              NaN
# 210         Yemen, Rep.            0.20       610.357367         6.265789
# 211              Zambia            3.56       432.226337        12.019036
# 212            Zimbabwe            4.96       320.771890        13.905267
#
#      employrate  urbanrate
# 0     55.700001      24.04
# ...

# %%
mexico = info[info['country'] == 'Mexico']

# %%
mexico
# Out:
#     country  alcconsumption  incomeperperson  suicideper100th  employrate  \
# 124  Mexico            8.55      6105.280743         4.288574   57.900002
#
#      urbanrate
# 124       77.2

# %%
mexico.set_index('country', inplace = True)

# %%
axs = info.hist(layout = (1,5), figsize = (25,3))
for i in range (axs.shape[1]):
  axs[0, i].text(mexico.iloc[0, i], 0, 'MEX', weight = 'bold', color = 'white')

# %%
axs.shape
# Out:
# (1, 5)

# %%
for i in range (axs.shape[1]):
  axs[0, i].text(mexico.iloc[0, i], 0, 'MEX', weight = 'bold', color = 'white')

# %%
axs
# Out:
# array([[<Axes: title={'center': 'alcconsumption'}>,
#         <Axes: title={'center': 'incomeperperson'}>,
#         <Axes: title={'center': 'suicideper100th'}>,
#         <Axes: title={'center': 'employrate'}>,
#         <Axes: title={'center': 'urbanrate'}>]], dtype=object)

# %% [markdown]
# **SEGUNDO EJERCICIO**

# %%
# Incorrecto pues se eliminan del dataframe original todos los registros donde sí hubo NAN
info.dropna(axis = 0, subset = ['alcconsumption'], inplace = True)
plt.boxplot(info['alcconsumption'], labels = ['Litres pure alcohol'])
plt.title('Alcohol consumption per adult (age 15+)')
# Out:
# Text(0.5, 1.0, 'Alcohol consumption per adult (age 15+)')

# %%
# Correcto pues los NAN solo se eliminan para efectos de la gráfica
plt.boxplot(info['alcconsumption'].dropna(), labels = ['Litres pure alcohol'])
plt.title('Alcohol consumption per adult (age 15+)')
# Out:
# Text(0.5, 1.0, 'Alcohol consumption per adult (age 15+)')

# %% [markdown]
# **TERCER EJERCICIO**

# %%
info.plot(kind = 'scatter', x = 'alcconsumption', logy = True )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-303db8650621> in <cell line: 1>()
# ----> 1 info.plot(kind = 'scatter', x = 'alcconsumption', logy = True )
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     943         if kind in self._dataframe_kinds:
#     944             if isinstance(data, ABCDataFrame):
# --> 945                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     946             else:
#     947                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      68                 ax = plt.gca()
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
pd.plotting.scatter_matrix(info, figsize = (10,10))
# Out:
# array([[<Axes: xlabel='alcconsumption', ylabel='alcconsumption'>,
#         <Axes: xlabel='incomeperperson', ylabel='alcconsumption'>,
#         <Axes: xlabel='suicideper100th', ylabel='alcconsumption'>,
#         <Axes: xlabel='employrate', ylabel='alcconsumption'>,
#         <Axes: xlabel='urbanrate', ylabel='alcconsumption'>],
#        [<Axes: xlabel='alcconsumption', ylabel='incomeperperson'>,
#         <Axes: xlabel='incomeperperson', ylabel='incomeperperson'>,
#         <Axes: xlabel='suicideper100th', ylabel='incomeperperson'>,
#         <Axes: xlabel='employrate', ylabel='incomeperperson'>,
#         <Axes: xlabel='urbanrate', ylabel='incomeperperson'>],
#        [<Axes: xlabel='alcconsumption', ylabel='suicideper100th'>,
#         <Axes: xlabel='incomeperperson', ylabel='suicideper100th'>,
#         <Axes: xlabel='suicideper100th', ylabel='suicideper100th'>,
#         <Axes: xlabel='employrate', ylabel='suicideper100th'>,
# ...

# %%
info.plot.scatter(x = 'alcconsumption', y = 'incomeperperson')
plt.yscale('log')
info.plot.scatter(x = 'alcconsumption', y = 'suicideper100th')
info.plot.scatter(x = 'alcconsumption', y = 'employrate')
info.plot.scatter(x = 'alcconsumption', y = 'urbanrate')
# Out:
# <Axes: xlabel='alcconsumption', ylabel='urbanrate'>
